# %%
import pandas as pd
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-304dfa65-369f-468e-bcc5-08285fe5fe39" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-304dfa65-369f-468e-bcc5-08285fe5fe39">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving country_timeseries.csv to country_timeseries (1).csv

# %%
df = pd.read_csv('country_timeseries.csv')

# %%
df.head()
# Out:
#          Date  Day  ...  Deaths_Spain  Deaths_Mali
# 0    1/5/2015  289  ...           NaN          NaN
# 1    1/4/2015  288  ...           NaN          NaN
# 2    1/3/2015  287  ...           NaN          NaN
# 3    1/2/2015  286  ...           NaN          NaN
# 4  12/31/2014  284  ...           NaN          NaN
#
# [5 rows x 18 columns]

# %% [markdown]
# ## Column headers are values, not variable names

# %%
df_formatted = pd.melt(df, id_vars=['Date', 'Day'], var_name='Region', value_name='Case_Count')

# %%
df_formatted.head()
# Out:
#          Date  Day        Region  Case_Count
# 0    1/5/2015  289  Cases_Guinea      2776.0
# 1    1/4/2015  288  Cases_Guinea      2775.0
# 2    1/3/2015  287  Cases_Guinea      2769.0
# 3    1/2/2015  286  Cases_Guinea         NaN
# 4  12/31/2014  284  Cases_Guinea      2730.0

# %% [markdown]
# ## Multiple variables are stored in one column

# %%
df_formatted[['Stats', 'Country']] = (df_formatted['Region'].str.split('_', expand=True))

# %%
df_formatted.head()
# Out:
#          Date  Day        Region  Case_Count  Stats Country
# 0    1/5/2015  289  Cases_Guinea      2776.0  Cases  Guinea
# 1    1/4/2015  288  Cases_Guinea      2775.0  Cases  Guinea
# 2    1/3/2015  287  Cases_Guinea      2769.0  Cases  Guinea
# 3    1/2/2015  286  Cases_Guinea         NaN  Cases  Guinea
# 4  12/31/2014  284  Cases_Guinea      2730.0  Cases  Guinea

# %%
df_formatted = df_formatted[['Date', 'Day', 'Country', 'Case_Count', 'Stats']]

# %%
df_formatted.head()
# Out:
#          Date  Day Country  Case_Count  Stats
# 0    1/5/2015  289  Guinea      2776.0  Cases
# 1    1/4/2015  288  Guinea      2775.0  Cases
# 2    1/3/2015  287  Guinea      2769.0  Cases
# 3    1/2/2015  286  Guinea         NaN  Cases
# 4  12/31/2014  284  Guinea      2730.0  Cases

# %% [markdown]
# ## Variables stored in both rows and columns

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9d93b777-bf1a-4c7e-a357-8fc50c6e8a5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d93b777-bf1a-4c7e-a357-8fc50c6e8a5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weather.csv to weather.csv

# %%
weather_df = pd.read_csv('weather.csv')

# %%
weather_df.head()
# Out:
#         id  year  month element  d1    d2  ...  d26  d27  d28  d29   d30  d31
# 0  MX17004  2010      1    tmax NaN   NaN  ...  NaN  NaN  NaN  NaN  27.8  NaN
# 1  MX17004  2010      1    tmin NaN   NaN  ...  NaN  NaN  NaN  NaN  14.5  NaN
# 2  MX17004  2010      2    tmax NaN  27.3  ...  NaN  NaN  NaN  NaN   NaN  NaN
# 3  MX17004  2010      2    tmin NaN  14.4  ...  NaN  NaN  NaN  NaN   NaN  NaN
# 4  MX17004  2010      3    tmax NaN   NaN  ...  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 35 columns]

# %%
weather_df.shape
# Out:
# (22, 35)

# %%
weather_formatted = weather_df.melt(id_vars=['id', 'year', 'month', 'element'], var_name='day', value_name='temp')

# %%
weather_formatted.head()
# Out:
#         id  year  month element day  temp
# 0  MX17004  2010      1    tmax  d1   NaN
# 1  MX17004  2010      1    tmin  d1   NaN
# 2  MX17004  2010      2    tmax  d1   NaN
# 3  MX17004  2010      2    tmin  d1   NaN
# 4  MX17004  2010      3    tmax  d1   NaN

# %%
weather_formatted.shape
# Out:
# (682, 6)

# %%
weather_formatted = weather_formatted.pivot_table(
    index=['id', 'year', 'month', 'day'],
    columns='element',
    values='temp'
)

weather_formatted = weather_formatted.reset_index()

# %%
weather_formatted.shape
# Out:
# (33, 6)

# %%
weather_formatted.head()
# Out:
# element       id  year  month  day  tmax  tmin
# 0        MX17004  2010      1  d30  27.8  14.5
# 1        MX17004  2010      2  d11  29.7  13.4
# 2        MX17004  2010      2   d2  27.3  14.4
# 3        MX17004  2010      2  d23  29.9  10.7
# 4        MX17004  2010      2   d3  24.1  14.4
